# %%
import numpy as np

# %%
from skimage import data

# %%
astronaut=data.astronaut()

# %%
astronaut
# Out:
# array([[[154, 147, 151],
#         [109, 103, 124],
#         [ 63,  58, 102],
#         ...,
#         [127, 120, 115],
#         [120, 117, 106],
#         [125, 119, 110]],
#
#        [[177, 171, 171],
#         [144, 141, 143],
#         [113, 114, 124],
#         ...,
#         [127, 118, 112],
#         [124, 115, 108],
#         [121, 116, 105]],
#
#        [[201, 194, 193],
#         [182, 178, 175],
#         [168, 165, 164],
#         ...,
#         [128, 120, 117],
#         [126, 116, 112],
#         [124, 114, 109]],
#
#        ...,
#
#        [[186, 170, 176],
#         [186, 170, 177],
#         [183, 168, 170],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   1],
#         [  0,   0,   0]],
#
#        [[183, 169, 170],
#         [182, 167, 171],
#         [185, 164, 176],
#         ...,
#         [  0,   0,   1],
#         [  1,   1,   1],
#         [  0,   0,   0]],
#
#        [[184, 167, 172],
#         [183, 165, 169],
#         [180, 162, 171],
# ...

# %%
astronaut.size
# Out:
# 786432

# %%
astronaut.shape
# Out:
# (512, 512, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(astronaut)

# %%
a=astronaut[100:,50:]

# %%
plt.imshow(a)

# %%
a1,a2=np.split(astronaut,2)

# %%
plt.imshow(a1)

# %%
plt.imshow(a2)

# %%
b1,b2=np.split(astronaut,2,axis=1)

# %%
plt.imshow(b1)

# %%
plt.imshow(b2)

# %%
plt.imshow(np.concatenate((a1,a2)))

# %%
plt.imshow(np.concatenate((b1,b2)))

# %%
import pandas as pd

# %%
import numpy as np

# %%
river = ['Ganges', 'Yamuna', 'Nile', 'Missisipi', 'Brazos']

# %%
rever_ser=pd.Series(river)

# %%
rever_ser
# Out:
# 0       Ganges
# 1       Yamuna
# 2         Nile
# 3    Missisipi
# 4       Brazos
# dtype: object

# %%
arr1=np.array([10,20,30,40,50])

# %%
ser=pd.Series(arr1,index = list('abcde'))

# %%
ser
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int32

# %%
ser=pd.Series(arr1,index = range(1,6))

# %%
ser
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# dtype: int32

# %%
emp_info = {'Name':'ABC', 'Id':101, 'sal':10000}

# %%
ser=pd.Series(emp_info)

# %%
ser
# Out:
# Name      ABC
# Id        101
# sal     10000
# dtype: object

# %%
state = ['AP', 'KA', 'KL', 'TN', 'UP']
capital = ['Amrawati', 'Karnataka', 'ThiruvanantPuram', 'Chennai', 'Lucknow']

# %%
state_capital=pd.Series(index=state,data=capital)

# %%
state_capital
# Out:
# AP            Amrawati
# KA           Karnataka
# KL    ThiruvanantPuram
# TN             Chennai
# UP             Lucknow
# dtype: object

# %%
state_capital.index
# Out:
# Index(['AP', 'KA', 'KL', 'TN', 'UP'], dtype='object')

# %%
state_capital.values
# Out:
# array(['Amrawati', 'Karnataka', 'ThiruvanantPuram', 'Chennai', 'Lucknow'],
#       dtype=object)

# %%
state_capital[0:2]
# Out:
# AP     Amrawati
# KA    Karnataka
# dtype: object

# %%
state_capital['AP':'KL']
# Out:
# AP            Amrawati
# KA           Karnataka
# KL    ThiruvanantPuram
# dtype: object

# %%
state_capital[['AP','KL']]
# Out:
# AP            Amrawati
# KL    ThiruvanantPuram
# dtype: object

# %%
# state_capital.sort_values

# %%
state_capital.sort_index()
# Out:
# AP            Amrawati
# KA           Karnataka
# KL    ThiruvanantPuram
# TN             Chennai
# UP             Lucknow
# dtype: object

# %%
import pandas as pd

# %%
df= pd.DataFrame()

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
continents_name = ['Asia', 
                   'Africa', 
                   'North America', 
                   'South America',
                   'Antarctica', 
                   'Europe', 
                   'Australia']

# %%
continents_name
# Out:
# ['Asia',
#  'Africa',
#  'North America',
#  'South America',
#  'Antarctica',
#  'Europe',
#  'Australia']

# %%
cont_name=pd.DataFrame(continents_name,columns=['continents_name'])

# %%
cont_name
# Out:
#   continents_name
# 0            Asia
# 1          Africa
# 2   North America
# 3   South America
# 4      Antarctica
# 5          Europe
# 6       Australia

# %%
continents_area = [44579000, 
                   30370000, 
                   24709000, 
                   17840000, 
                   14000000, 
                   10180000, 
                   8600000]

# %%
area_df=pd.DataFrame(continents_area,columns=['continents_area'])

# %%
area_df
# Out:
#    continents_area
# 0         44579000
# 1         30370000
# 2         24709000
# 3         17840000
# 4         14000000
# 5         10180000
# 6          8600000

# %%
continet_detail=list(zip(continents_name,continents_area))

# %%
continet_detail
# Out:
# [('Asia', 44579000),
#  ('Africa', 30370000),
#  ('North America', 24709000),
#  ('South America', 17840000),
#  ('Antarctica', 14000000),
#  ('Europe', 10180000),
#  ('Australia', 8600000)]

# %%
continet_detail_df=pd.DataFrame(continet_detail, columns=['Name','Area'])

# %%
continet_detail_df
# Out:
#             Name      Area
# 0           Asia  44579000
# 1         Africa  30370000
# 2  North America  24709000
# 3  South America  17840000
# 4     Antarctica  14000000
# 5         Europe  10180000
# 6      Australia   8600000

# %%
avg_wts=pd.read_csv('/c/Users/ENATYAV/Desktop/Datascience/LB_DS_WKND_OCT_11/Pandas/Average_weight.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-108-be238dc1bb81> in <module>
# ----> 1 avg_wts=pd.read_csv('/c/Users/ENATYAV/Desktop/Datascience/LB_DS_WKND_OCT_11/Pandas/Average_weight.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
